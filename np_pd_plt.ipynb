# %%
import numpy as np
import pandas as pd

# %%
series=pd.Series([1,2,3,np.nan,4,5])
print(series)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
dates=pd.date_range("20210101",periods=6)
print(dates)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6,4)
# Out:
# array([[ 0.96512056,  0.21380233,  0.04340553,  0.36473728],
#        [ 1.48522291, -0.4451751 ,  0.38763021, -1.17050321],
#        [-0.71164342, -0.83275111, -0.12999129, -0.52684386],
#        [ 0.25436901,  0.09855376, -0.79145049,  0.87695712],
#        [-2.00385644, -0.48052414,  0.11960665, -0.83010913],
#        [ 0.24200758,  0.39395454, -0.55814455,  0.33682674]])

# %%
list("ABCD")
# Out:
# ['A', 'B', 'C', 'D']

# %%
df= pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))
#df.index --> row index
#df.colums --> Column index

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -0.158895  2.334653 -1.729443 -0.494192
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477
# 2021-01-04 -0.067356 -0.133012 -1.095781 -0.531394
# 2021-01-05 -0.382091  1.267662  0.043235  1.295610
# 2021-01-06  0.035272 -0.847161  0.399785  0.447109

# %%
help(pd.date_range)
# Out:
# Help on function date_range in module pandas.core.indexes.datetimes:
#
# date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize=False, name=None, closed=None, **kwargs)
#     Return a fixed frequency DatetimeIndex.
#
#     Parameters
#     ----------
#     start : str or datetime-like, optional
#         Left bound for generating dates.
#     end : str or datetime-like, optional
#         Right bound for generating dates.
#     periods : integer, optional
#         Number of periods to generate.
#     freq : str or DateOffset, default 'D'
#         Frequency strings can have multiples, e.g. '5H'. See
#         :ref:`here <timeseries.offset_aliases>` for a list of
#         frequency aliases.
#     tz : str or tzinfo, optional
#         Time zone name for returning localized DatetimeIndex, for example
#         'Asia/Hong_Kong'. By default, the resulting DatetimeIndex is
#         timezone-naive.
#     normalize : bool, default False
# ...

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df.B
# Out:
# 2021-01-01    2.334653
# 2021-01-02    0.967986
# 2021-01-03   -0.217348
# 2021-01-04   -0.133012
# 2021-01-05    1.267662
# 2021-01-06   -0.847161
# Freq: D, Name: B, dtype: float64

# %%
df.head()
# Out:
#                    A         B         C         D
# 2021-01-01 -0.158895  2.334653 -1.729443 -0.494192
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477
# 2021-01-04 -0.067356 -0.133012 -1.095781 -0.531394
# 2021-01-05 -0.382091  1.267662  0.043235  1.295610

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2021-01-05 -0.382091  1.267662  0.043235  1.295610
# 2021-01-06  0.035272 -0.847161  0.399785  0.447109

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.073940  0.055352 -0.540514 -0.300972
# std    0.780263  1.356321  1.005753  0.457470
# min   -0.881336 -1.593027 -2.475347 -1.010061
# 25%   -0.649049 -1.056558 -0.471758 -0.579566
# 50%   -0.246255  0.236022 -0.337714 -0.137848
# 75%    0.380408  1.124505 -0.101253  0.023220
# max    1.124222  1.519846  0.446563  0.129820

# %%
#Transposing your Data
df.T
# Out:
#    2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  2021-01-06
# A   -0.158895    0.501581   -1.174375   -0.067356   -0.382091    0.035272
# B    2.334653    0.967986   -0.217348   -0.133012    1.267662   -0.847161
# C   -1.729443   -2.257998    0.849376   -1.095781    0.043235    0.399785
# D   -0.494192   -0.439134   -1.828477   -0.531394    1.295610    0.447109

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -0.158895  2.334653 -1.729443 -0.494192
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477
# 2021-01-04 -0.067356 -0.133012 -1.095781 -0.531394
# 2021-01-05 -0.382091  1.267662  0.043235  1.295610
# 2021-01-06  0.035272 -0.847161  0.399785  0.447109

# %%
df["A"]
# Out:
# 2021-01-01   -0.158895
# 2021-01-02    0.501581
# 2021-01-03   -1.174375
# 2021-01-04   -0.067356
# 2021-01-05   -0.382091
# 2021-01-06    0.035272
# Freq: D, Name: A, dtype: float64

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477

# %%
df["20210102":"20210104"]
# Out:
#                    A         B         C         D
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477
# 2021-01-04 -0.067356 -0.133012 -1.095781 -0.531394

# %%
dates[0]
# Out:
# Timestamp('2021-01-01 00:00:00', freq='D')

# %%
df.loc[dates[0]]
# Out:
# A   -0.158895
# B    2.334653
# C   -1.729443
# D   -0.494192
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2021-01-01 -0.158895  2.334653 -1.729443 -0.494192
# 2021-01-02  0.501581  0.967986 -2.257998 -0.439134
# 2021-01-03 -1.174375 -0.217348  0.849376 -1.828477
# 2021-01-04 -0.067356 -0.133012 -1.095781 -0.531394
# 2021-01-05 -0.382091  1.267662  0.043235  1.295610
# 2021-01-06  0.035272 -0.847161  0.399785  0.447109

# %%
findColumnLabels=["B","D"]
df.loc[:,findColumnLabels]
# Out:
#                    B         D
# 2021-01-01  2.334653 -0.494192
# 2021-01-02  0.967986 -0.439134
# 2021-01-03 -0.217348 -1.828477
# 2021-01-04 -0.133012 -0.531394
# 2021-01-05  1.267662  1.295610
# 2021-01-06 -0.847161  0.447109

# %%
findColumnLabels=["B","C"]

df.loc["20210102":"20210104",findColumnLabels]
# Out:
#                    B         C
# 2021-01-02  0.967986 -2.257998
# 2021-01-03 -0.217348  0.849376
# 2021-01-04 -0.133012 -1.095781

# %%
import pandas as pd

df = pd.DataFrame({'Age': [30, 20, 22, 40, 32, 28, 39],
                   'Color': ['Blue', 'Green', 'Red', 'White', 'Gray', 'Black',
                             'Red'],
                   'Food': ['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese',
                            'Melon', 'Beans'],
                   'Height': [165, 70, 120, 80, 180, 172, 150],
                   'Score': [4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2],
                   'State': ['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX']
                   },
                  index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean',
                         'Christina', 'Cornelia'])
df
# Out:
#            Age  Color    Food  Height  Score State
# Jane        30   Blue   Steak     165    4.6    NY
# Nick        20  Green    Lamb      70    8.3    TX
# Aaron       22    Red   Mango     120    9.0    FL
# Penelope    40  White   Apple      80    3.3    AL
# Dean        32   Gray  Cheese     180    1.8    AK
# Christina   28  Black   Melon     172    9.5    TX
# Cornelia    39    Red   Beans     150    2.2    TX

# %%
df.loc[df["Age"]<30,["Color","Height"]]
# Out:
#            Color  Height
# Nick       Green      70
# Aaron        Red     120
# Christina  Black     172

# %%
df.iloc[ (df["Age"]<30).values,[1,3]]
# Out:
#            Color  Height
# Nick       Green      70
# Aaron        Red     120
# Christina  Black     172

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- -------------------
# absl-py                 0.11.0
# aiohttp                 3.7.3
# alembic                 1.4.2
# altair                  3.1.0
# astor                   0.8.1
# async-generator         1.10
# async-timeout           3.0.1
# attrs                   19.3.0
# backcall                0.2.0
# bleach                  3.1.5
# blinker                 1.4
# bokeh                   2.2.3
# bqplot                  0.12.20
# branca                  0.3.1
# brotlipy                0.7.0
# cached-property         1.5.2
# certifi                 2020.12.5
# certipy                 0.1.3
# cffi                    1.14.0
# chardet                 3.0.4
# click                   7.1.2
# cloudpickle             1.6.0
# cryptography            3.0
# cycler                  0.10.0
# cytoolz                 0.11.0
# dask                    2.1.0
# decorator               4.4.2
# defusedxml              0.6.0
# ...

# %%
import matplotlib.pyplot as plt

myLine=[5,15]
plt.plot(myLine)


plt.title("Interactive Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
import matplotlib.pyplot as plt

Java=[5,15]
Python=[3,6]
C=[8.00,14,12]
plt.plot(Java,label="Java")
plt.plot(Python,label="Python")
plt.plot(C,label="C")

plt.legend()

# %%
import matplotlib.pyplot as plt
 
# Changing default values for parameters individually
plt.rc('lines', linewidth=2, linestyle='-', marker='*')
plt.rcParams['lines.markersize'] = 10
plt.rcParams['font.size'] = '10.0'
 
#Plot a line graph
plt.plot([10, 20, 30, 40, 50])

# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
 
plt.show()

# %%
data1 = [11, 12, 13, 14, 15, 16, 17]
data2 = [15.5, 12.5, 11.7, 9.50, 12.50, 11.50, 14.75]

plt.grid(True,linewidth=0.5,color="#ff0000",linestyle="-")


# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Set the limit for each axis
plt.xlim(11, 17)
plt.ylim(9, 16)


plt.plot(data1,data2)

#plt.savefig("aaa.png",bbox_inches="tight")
plt.savefig("bbb.pdf",format="pdf",dpi=1200,bbox_inches="tight")
