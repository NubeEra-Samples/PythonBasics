# %%
print("Welcome to Python")   # Shift+Enter
# Out:
# Welcome to Python

# %%
25+5
# Out:
# 30

# %%
# !mkdir Mujahed
# Out:
# mkdir: cannot create directory ‘Mujahed’: File exists

# %%
# !ls -ltra
# Out:
# total 181800
# drwxr-xr-x 2 jovyan jovyan      4096 Jan 21 11:32 data
# drwxr-xr-x 4 jovyan jovyan      4096 Jan 21 11:46 TCGA_Data
# drwxr-xr-x 4 jovyan jovyan      4096 Jan 21 11:46 notebooks
# -rw-r--r-- 1 jovyan jovyan      1224 Jan 21 11:46 markdown_python.md
# -rw-r--r-- 1 jovyan jovyan      1357 Jan 21 11:46 lorenz.py
# -rw-r--r-- 1 jovyan jovyan      3706 Jan 21 11:46 Lorenz.ipynb
# -rw-r--r-- 1 jovyan jovyan   3526397 Jan 21 11:46 jupyterlab-slides.pdf
# -rw-r--r-- 1 jovyan jovyan      2974 Jan 21 11:46 jupyterlab.md
# -rwxr-xr-x 1 jovyan jovyan 182578664 Jan 21 11:46 big.csv
# drwxr-xr-x 1 jovyan jovyan      4096 Jan 25 09:24 ..
# drwxr-xr-x 2 jovyan root        4096 Jan 25 09:28 Mujahed
# -rw-r--r-- 1 jovyan root          72 Jan 25 09:32 Untitled1.ipynb
# drwxr-xr-x 2 jovyan root        4096 Jan 25 09:32 .ipynb_checkpoints
# -rw-r--r-- 1 jovyan root        2061 Jan 25 09:36 Untitled.ipynb
# drwxr-xr-x 1 jovyan jovyan      4096 Jan 25 09:36 .

# %% [raw]
# print("Welcome")

# %% [markdown]
# # Welcome

# %%
s1="Welcome"
s1=s1*3
print(s1)
# Out:
# WelcomeWelcomeWelcome

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
s1.lower()
# Out:
# 'welcomewelcomewelcome'

# %%
help(s1.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
if True:
    print("True Condition")
else:
    print("False Condition")
# Out:
# True Condition

# %%
str_num=input("Enter Number: ")
int_num=int(str_num)
if int_num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")
# Out:
# Enter Number:  25
# Positive or Zero

# %%
str_num=input("Enter Number: ")
num=int(str_num)
if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Enter Number:  -5
# Negative number

# %%
name="Mujahed"
for n in name:
    print(n, end="\t")
# Out:
# M	u	j	a	h	e	d

# %%
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
sum=0
for val in numbers:
    sum = sum+val
print(sum)
# Out:
# 48

# %%
entryRange = range(5, 51,5)
for entry in entryRange:
    print(entry,end=" ")
# Out:
# 5 10 15 20 25 30 35 40 45 50

# %%
a=10
type(a)
# Out:
# int

# %%
a="Mujahed"
type(a)
# Out:
# str
